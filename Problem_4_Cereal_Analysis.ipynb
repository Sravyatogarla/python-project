# %% [markdown]
# ## Problem Statement - 4

# %% [markdown]
# # Cereals Analysis

# %% [markdown]
# ~ Sylphia has a dataset of various cereals sold in the supermarket.Dataset Description:cereal.csv- The dataset contains 16 features.
#
# Here's a brief description of 3 columns in the dataset:
#  •name - Brand name of the cereals•MFR - Manufacturer of the brands
#  •rating - Rating of the cerealsSyliphia wants to visualize the quality of cereals and determine which manufacturer delivers the best quality.
#
#  Tasks to be performed:
#  1.Import the dataset.
#  2.Plot ratings of different types of manufacturers.
#  3.Use xticks range form 0-100.
#  4.Change the style of the graph to seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

#import the cerials.csv dataset
df=pd.read_csv("cereal.csv")
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6   280.0        25      3     1.0  0.33  68.402973
# 1     8.0       8   135.0         0      3     1.0  1.00  33.983679
# 2     7.0       5   320.0        25      3     1.0  0.33  59.425505
# 3     8.0       0   330.0        25      3     1.0  0.50  93.704912
# 4    14.0       8     NaN        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3    60.0        25      3     1.0  0.75  39.106174
# 73   13.0      12    25.0        25      2     1.0  1.00  27.753301
# 74   17.0       3   115.0        25      1     1.0  0.67  49.787445
# 75   17.0       3   110.0        25      1     1.0  1.00  51.592193
# 76   16.0       8    60.0        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
#2 plot ratings of different types of manufacturers.
data=df.groupby("mfr",as_index=False).sum()
data
# Out:
#   mfr                                               name  \
# 0   A                                              Maypo
# 1   G  Apple Cinnamon CheeriosBasic 4CheeriosCinnamon...
# 2   K  All-BranAll-Bran with Extra FiberApple JacksCo...
# 3   N  100% BranCream of Wheat (Quick)Shredded WheatS...
# 4   P  Bran FlakesFruit & Fibre Dates; Walnuts; and O...
# 5   Q  100% Natural BranCap'n'CrunchHoney Graham OhsL...
# 6   R  Almond DelightBran ChexCorn ChexDouble ChexMue...
#
#                       type  calories  protein  fat  sodium  fiber  carbo  \
# 0                        H       100        4    1       0    0.0   16.0
# 1   CCCCCCCCCCCCCCCCCCCCCC      2450       51   30    4410   28.0  324.0
# 2  CCCCCCCCCCCCCCCCCCCCCCC      2500       61   14    4020   63.0  348.0
# 3                   CHCCCC       520       17    1     225   24.0   96.0
# 4                CCCCCCCCC       980       22    8    1315   25.0  119.0
# 5                 CCCCCCCH       760       21   14     740   10.7   81.0
# 6                 CCCCCCCC       920       20   10    1585   15.0  141.0
#
#    sugars  potass  vitamins  shelf  weight   cups       rating
# 0       3    95.0        25      2    1.00   1.00    54.850917
# 1     175  1875.0       775     47   23.08  19.25   758.688737
# 2     174  2370.0       800     54   24.79  18.31  1012.884634
# 3      11   725.0        50     10    5.83   4.67   407.811403
# 4      79  1025.0       225     22    9.58   6.43   375.351697
# 5      43   595.0       100     19    7.00   6.59   343.327919
# 6      49   715.0       200     16    8.00   6.97   332.343977

# %%
#3 xticks range form 0-100

plt.barh(data["mfr"], data["rating"], color='skyblue')

plt.xticks(np.arange(0,100,1000))
                    
#4 change the style of the graph to seaborn

sns.set_style("whitegrid")

plt.show()
